# %%
import pandas as pd
import pickle
import os

# %%
data_path = 'Data'
all_path = 'Data/All'
domain_path = 'Data/Domain'
field_path = 'Data/Field'
topic_path = 'Data/Topic'

# %%
institutions_info_df_selected = pd.read_csv(os.path.join(data_path, "institutions_info_df_selected.csv.gz"), compression="gzip")
institutions_relationships_df_selected = pd.read_csv(os.path.join(data_path, "institutions_relationships_df_selected.csv.gz"), compression="gzip")
df_topics = pd.read_csv(os.path.join(data_path, 'df_topics.csv.gz'), compression='gzip')
dict_institution_id_name = pickle.load(open(os.path.join(data_path, 'dict_institution_id_name.pkl'), "rb"))

# %%
type_ = 'geom2'

# %%
RCA_df_selected_all = pd.read_csv(os.path.join(all_path, "RCA_df_selected.csv.gz"), compression="gzip") 
institutions_stats_selected_all = pd.read_csv(os.path.join(all_path, "institutions_stats_selected.csv.gz"), compression="gzip")
institutions_stats_periods_selected_all = pd.read_csv(os.path.join(all_path, "institutions_stats_periods_selected.csv.gz"), compression="gzip")
edges_df_selected_dict_all = pickle.load(open(os.path.join(all_path, 'edges_df_selected_dict.pkl'), "rb"))
entropy_df_selected_all = pd.read_csv(os.path.join(all_path, "entropy_df_selected.csv.gz"), compression="gzip")
institution_peers_dict_all = pickle.load(open(os.path.join(all_path, 'institution_peers_selected_dict.pkl'), "rb"))[type_]
impact_selected_all = pd.read_csv(os.path.join(all_path, "institutions_impact_rev_selected.csv.gz"), compression="gzip")

# %%
RCA_df_selected_bydomain_dict = pickle.load(open(os.path.join(domain_path, 'RCA_df_selected_bydomain_dict.pkl'), "rb"))
institutions_stats_selected_bydomain_dict = pickle.load(open(os.path.join(domain_path, 'institutions_stats_selected_bydomain_dict.pkl'), "rb"))
institutions_stats_periods_selected_bydomain_dict = pickle.load(open(os.path.join(domain_path, 'institutions_stats_periods_selected_bydomain_dict.pkl'), "rb"))
edges_df_selected_bydomain_dict = pickle.load(open(os.path.join(domain_path, 'edges_df_selected_bydomain_dict.pkl'), "rb"))[type_]
entropy_df_selected_bydomain_dict = pickle.load(open(os.path.join(domain_path, 'entropy_df_selected_bydomain_dict.pkl'), "rb"))
institution_peers_bydomain_dict = pickle.load(open(os.path.join(domain_path, 'institution_peers_selected_bydomain_dict.pkl'), "rb"))[type_]
impact_selected_bydomain_dict = pickle.load(open(os.path.join(domain_path, 'institutions_impact_rev_selected_bydomain_dict.pkl'), "rb"))

# %%
RCA_df_selected_byfield_dict = pickle.load(open(os.path.join(field_path, 'RCA_df_selected_byfield_dict.pkl'), "rb"))
institutions_stats_selected_byfield_dict = pickle.load(open(os.path.join(field_path, 'institutions_stats_selected_byfield_dict.pkl'), "rb"))
institutions_stats_periods_selected_byfield_dict = pickle.load(open(os.path.join(field_path, 'institutions_stats_periods_selected_byfield_dict.pkl'), "rb"))
edges_df_selected_byfield_dict = pickle.load(open(os.path.join(field_path, 'edges_df_selected_byfield_dict.pkl'), "rb"))[type_]
entropy_df_selected_byfield_dict = pickle.load(open(os.path.join(field_path, 'entropy_df_selected_byfield_dict.pkl'), "rb"))
institution_peers_byfield_dict = pickle.load(open(os.path.join(field_path, 'institution_peers_selected_byfield_dict.pkl'), "rb"))[type_]
impact_selected_byfield_dict = pickle.load(open(os.path.join(field_path, 'institutions_impact_rev_selected_byfield_dict.pkl'), "rb"))

# %%
RCA_topic_df_selected_all = pd.read_csv(os.path.join(topic_path, "RCA_topic_df_selected.csv.gz"), compression="gzip")
topics_embedding_reduced_df = pd.read_csv(os.path.join(topic_path, 'topics_embedding_reduced_weighted_df.csv.zip')).reset_index().rename(columns={'index':'topic_id_scaled'})
